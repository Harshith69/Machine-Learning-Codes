# %% [markdown]
# CHART GENERATING CODES

# %%
# Library for dataset upload
import pandas as pd

# %%
# for getting accss of gdrive file
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#import your dataframe
df = pd.read_csv('/content/Wheat_data23.csv')

# %%
df
# Out:
#             Date  Price
# 0     01-01-2002    845
# 1     02-01-2002    845
# 2     03-01-2002    840
# 3     04-01-2002    825
# 4     05-01-2002    839
# ...          ...    ...
# 7783  24-04-2023   2225
# 7784  25-04-2023   2460
# 7785  26-04-2023   2210
# 7786  27-04-2023   2350
# 7787  28-04-2023   2215
#
# [7788 rows x 2 columns]

# %%
#labeling price column
df1= df['Price']

# %%
import statsmodels.api as sm

# %%
#plotting auto correlation graph
fig = sm.graphics.tsa.plot_acf(df["Price"], lags=20)
fig.show()

# %%
#Plotting the distribution curve of price data
import matplotlib as mpl 
import matplotlib.pyplot as plt 
# create the plot
ax = df1.hist()

# set x and y axis labels
ax.set_xlabel("Price")
ax.set_ylabel("Frequency")

# show the plot
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
#plotting auto correlation and partial auto correlation graphs for price datasets
#library for graph
import matplotlib as mpl 
import matplotlib.pyplot as plt 
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(10,6))
plot_acf(df1, lags=40, ax=ax[0])
ax[0].set_title("Autocorrelation Function (ACF)")

plot_pacf(df1, lags=40, ax=ax[1])
ax[1].set_title("Partial Autocorrelation Function (PACF)")

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# perform first-order differencing and plotting the graph
df1_diff = df1.diff(periods=1)

# plot the original time series
# plt.plot(df1)
# plt.title('Original Time Series')
# plt.show()

# plot the differenced time series
plt.plot(df1_diff)
plt.title('First order differencing of Time Series')
plt.xlabel('Dates')
plt.ylabel('Price')
plt.show()

# %%
#plotting auto correlation and partial auto correlation graphs after first order differentiation
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(10,6))
plot_acf(df1_diff, lags=40, ax=ax[0])
ax[0].set_title("Autocorrelation Function (ACF)")

plot_pacf(df1_diff, lags=40, ax=ax[1])
ax[1].set_title("Partial Autocorrelation Function (PACF)")

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py:2503: UserWarning: Warning: converting a masked element to nan.
#   xys = np.asarray(xys)

# %%
#plotting the lag line chart to find correlation bw day lag period
import matplotlib.pyplot as plt
import pandas as pd

# Load data
# df = pd.read_csv("data.csv")

# Create lag line chart
plt.plot(df["Price"], df["Price"].shift(1), "o", alpha=0.5, color='red')
plt.title("Lag Line Chart")
plt.xlabel("Price(t)")
plt.ylabel("Price(t+1)")
plt.show()

# %%
#plotting time series bubble scatter plot
import matplotlib.pyplot as plt
import pandas as pd

# Load time series data from CSV file
data = pd.read_csv('/content/Wheat_data23.csv', index_col=0, parse_dates=True)

# Create scatter plot
fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(data.index, data['Price'], color='orange', alpha=0.5)

# Set plot title and axis labels
ax.set_title('Time Series Scatter Plot')
ax.set_xlabel('Date')
ax.set_ylabel('Price')

# Show plot
plt.show()
# Out:
# <ipython-input-14-5b073d8d057b>:6: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data = pd.read_csv('/content/Wheat_data23.csv', index_col=0, parse_dates=True)

# %%
#plotting box whisker plot to visualize the statistics
import numpy as np

# Plot box whisker plot
plt.boxplot(df1, vert=True)

# Set title and x-axis label
plt.title('Box Whisker Plot')
plt.xlabel('Price Difference')

# Add labels for quartiles and median
quartiles = np.percentile(df1, [25, 50, 75])
plt.text(0.85, quartiles[0], 'Q1')
plt.text(0.85, quartiles[1], 'Median')
plt.text(0.85, quartiles[2], 'Q3')

# Show plot
plt.show()

# %%
#plotting the distribution curve along with histogram
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load data
# df = pd.read_csv("data.csv")

# Set color palette
color = "magenta"

# Create distribution plot with custom colors
sns.displot(df["Price"], kde=True, color=color)
sns.set_style("darkgrid")
plt.title("Distribution of Time Series Data")
plt.xlabel("Price")
plt.show()

# %%
#plotting time series graph of price
import matplotlib.pyplot as plt

# create the plot with a larger size
fig, ax = plt.subplots(figsize=(10, 6))
df1.plot(color="limegreen", ax=ax)

# set x and y axis labels
ax.set_xlabel("Date")
ax.set_ylabel("Price")

# show the plot
plt.show()

# %%
#plotting the violin graph
import matplotlib.pyplot as plt

# create the plot
ax = plt.subplot()
ax.violinplot(df['Price'], showmedians=True)

# set x and y axis labels
ax.set_xlabel("Price")
ax.set_ylabel("Frequency")

# show the plot
plt.show()

# %%
import pandas as pd
import statsmodels.api as sm
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
ax.set_facecolor('white')

# Load data and set index to datetime
df = pd.read_csv('/content/Wheat_data23.csv')
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# Perform seasonal decomposition
decomposition = sm.tsa.seasonal_decompose(df, model='additive', period=12)

# Plot trend and residuals
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(decomposition.trend, color='indigo', label='Trend')
ax.plot(decomposition.resid, color='red', alpha=0.5, label='Residuals')
ax.legend(loc='upper left')
plt.show()
# Out:
# <ipython-input-24-d1b296f15b35>:10: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
